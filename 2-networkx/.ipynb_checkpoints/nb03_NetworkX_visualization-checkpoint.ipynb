# %% [markdown]
# <center>
# <hr>
# <h1>Complessità nei sistemi sociali</h1>
# <h2>Laurea Magistrale in Fisica Dei Sistemi Complessi</h2>
# <h2>A.A. 2016/17</h2>
# <h3>Dr. Daniela Paolotti, Dr. Michele Tizzoni</h3>
# <h3>Introduction to NetworkX - Network visualization</h3>
# <hr>
# </center>

# %% [markdown]
# # NetworkX preliminaries
# ---
#
# We will use the Python library [NetworkX](https://networkx.github.io/index.html). It is well documented and several [examples](http://networkx.readthedocs.io/en/networkx-1.11/examples/) are available.
#
# It is not the only Python library available for network analysis. Another very good one is [graph-tool](https://graph-tool.skewed.de/).
#
# Also the [SNAP library](http://snap.stanford.edu/data/index.html) provides an excellent tool to analyze very large networks.

# %%
import networkx as nx
from operator import itemgetter

# %% [markdown]
# We import the plotting library seaborn which integrates very well with matplotlib.
# More documentation is available here: https://seaborn.pydata.org/

# %%
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Generate an empty UNDIRECTED graph with NetworkX

# %%
G=nx.Graph()

# %% [markdown]
# Add nodes from a list of names

# %%
G.add_nodes_from(['Luca','Andrea','Sara','Carlo','Veronica'])

# %%
G.nodes()
# Out:
# ['Luca', 'Andrea', 'Sara', 'Carlo', 'Veronica']

# %% [markdown]
# Add another node

# %%
G.add_node('Giovanni')

print ("The nodes of G are: ")
print (G.nodes())
# Out:
# The nodes of G are:
# ['Luca', 'Andrea', 'Sara', 'Carlo', 'Veronica', 'Giovanni']

# %% [markdown]
# So far we have nodes in the networks but no edges.
# Let's add edges from a list of tuples.

# %%
G.add_edges_from([('Luca','Sara'),('Andrea','Luca'),
('Carlo','Veronica'),('Sara','Veronica'),('Giovanni','Andrea')])

# %% [markdown]
# We add another edge and 'Lucia' is a new node.

# %%
G.add_edge('Veronica','Lucia')

print ("The nodes of G are : ")
print (G.nodes())

print ("The links of G are : ")
print (G.edges())
# Out:
# The nodes of G are :
# ['Luca', 'Andrea', 'Sara', 'Carlo', 'Veronica', 'Giovanni', 'Lucia']
# The links of G are :
# [('Luca', 'Sara'), ('Luca', 'Andrea'), ('Andrea', 'Giovanni'), ('Sara', 'Veronica'), ('Carlo', 'Veronica'), ('Veronica', 'Lucia')]

# %% [markdown]
# We want to add the property 'age' to each node

# %%
G.node['Lucia']
# Out:
# {}

# %%
for n in G.nodes():
    if n[0]=='L':
        G.node[n]['age']=24
    else:
        G.node[n]['age']=28

#show the nodes with their age
print (G.nodes(data=True))
# Out:
# [('Luca', {'age': 24}), ('Andrea', {'age': 28}), ('Sara', {'age': 28}), ('Carlo', {'age': 28}), ('Veronica', {'age': 28}), ('Giovanni', {'age': 28}), ('Lucia', {'age': 24})]

# %% [markdown]
# How to remove a node?

# %%
G.remove_node('Luca')
print (G.nodes(data=True))
print (G.edges())
# Out:
# [('Andrea', {'age': 28}), ('Sara', {'age': 28}), ('Carlo', {'age': 28}), ('Veronica', {'age': 28}), ('Giovanni', {'age': 28}), ('Lucia', {'age': 24})]
# [('Andrea', 'Giovanni'), ('Sara', 'Veronica'), ('Carlo', 'Veronica'), ('Veronica', 'Lucia')]

# %% [markdown]
# If we remove an edge, we do not remove the nodes!

# %%
G.remove_edge('Giovanni', 'Andrea')

# %%
G.edges()
# Out:
# [('Sara', 'Veronica'), ('Carlo', 'Veronica'), ('Veronica', 'Lucia')]

# %% [markdown]
# Degree is easily accessible

# %%
G.degree('Veronica')
# Out:
# 3

# %%
G.degree()
# Out:
# {'Andrea': 0, 'Carlo': 1, 'Giovanni': 0, 'Lucia': 1, 'Sara': 1, 'Veronica': 3}

# %%
for i in G.degree():
    print (i, G.degree()[i])
# Out:
# Andrea 0
# Sara 1
# Carlo 1
# Veronica 3
# Giovanni 0
# Lucia 1

# %% [markdown]
# ## Analyze the citHepTh network with NetworkX
# ---
# We analyze the citation dataset (citHepTh) available on the [Stanford Large Network Data Colletion](http://snap.stanford.edu/data/index.html).
#
# The network is directed!

# %%
H=nx.DiGraph()

# %%
fh=open('./cit-HepTh.txt','r')
#reading all the file lines
for line in fh.readlines():
    #remove "\n" characters (.strip()) and split the line at blank spaces (split.())
    s=line.strip().split()
    if s[0]!='#':
        #the first lines are comments
        origin=int(s[0])
        dest=int(s[1])
        H.add_edge(origin,dest)
    
#chiudo il file
fh.close()

# %%
print ("The network has", len(H), "nodes")
# Out:
# The network has 27770 nodes

# %%
H.in_degree()
#this is a dictionary node->degree_in
# Out:
# {1001: 10,
#  9304045: 16,
#  9308122: 115,
#  9309097: 140,
#  9311042: 55,
#  9401139: 421,
#  9404151: 77,
#  9407087: 1299,
#  9408099: 1006,
#  9501030: 126,
#  9503124: 1114,
#  9504090: 337,
#  9504145: 192,
#  9505025: 30,
#  9505054: 63,
#  9505105: 327,
#  9505162: 205,
#  9506048: 49,
#  9506112: 189,
#  9506144: 77,
#  9507050: 160,
#  9507158: 301,
#  9508094: 90,
#  9508155: 192,
#  9510142: 35,
#  9510225: 175,
#  9510234: 92,
#  9511030: 329,
#  9511171: 49,
#  9601108: 95,
#  9602022: 520,
#  9602114: 252,
#  9603003: 194,
#  9603150: 148,
#  9603161: 274,
#  9603167: 467,
#  9605184: 148,
#  9605222: 24,
#  9606017: 110,
#  9606040: 118,
#  9607163: 186,
#  9607207: 127,
#  9608086: 28,
#  9609070: 81,
#  9609071: 65,
#  9609239: 145,
#  9611137: 139,
#  9612108: 37,
#  9701162: 114,
#  9702094: 62,
#  9702155: 63,
#  9702198: 59,
#  9703082: 49,
#  9703166: 424,
#  9704097: 29,
#  9705030: 70,
#  9705044: 71,
#  9705104: 65,
#  9705220: 39,
#  9706005: 11,
#  9707014: 16,
#  9707042: 43,
#  9707049: 16,
#  9710230: 139,
#  9711036: 8,
#  9711104: 17,
#  9712028: 129,
#  9712042: 14,
#  9802194: 22,
#  9805056: 17,
#  9805206: 11,
#  9806094: 22,
#  9810188: 328,
#  9811217: 24,
#  9905036: 14,
#  9907041: 12,
#  9908007: 11,
#  9908144: 54,
#  9909108: 23,
#  9909120: 22,
#  9909229: 18,
#  9910238: 11,
#  9910248: 5,
#  9910268: 5,
#  9905143: 10,
#  9907006: 25,
#  9905221: 65,
#  9906182: 141,
#  9808117: 37,
#  9811167: 30,
#  9901056: 35,
#  9906204: 27,
#  9906224: 26,
#  9907204: 21,
#  9908104: 35,
#  9703040: 146,
#  9704189: 23,
#  9908175: 16,
#  9908196: 11,
#  9808122: 14,
#  9209117: 2,
#  9909047: 129,
#  9804006: 24,
#  9902208: 35,
#  9905148: 23,
#  9906168: 25,
#  9906221: 34,
#  9909070: 116,
#  1033: 111,
#  2226: 35,
#  9702056: 22,
#  9907080: 20,
#  9908174: 11,
#  9909076: 24,
#  9910132: 89,
#  9911055: 191,
#  9808032: 65,
#  9903238: 79,
#  9906040: 18,
#  9908047: 26,
#  9910081: 21,
#  9909103: 24,
#  9806217: 49,
#  9903190: 74,
#  9903241: 27,
#  9301052: 131,
#  9612014: 5,
#  9705223: 12,
#  9909130: 93,
#  9909205: 111,
#  9911043: 89,
#  9912001: 138,
#  9912233: 62,
#  9405029: 113,
#  9705117: 110,
#  9902067: 26,
#  9903091: 26,
#  9905081: 25,
#  9908110: 10,
#  9910252: 15,
#  9911040: 31,
#  9911161: 138,
#  9911199: 12,
#  1003: 15,
#  9912242: 21,
#  9909127: 13,
#  9910269: 3,
#  9912160: 75,
#  1004: 1,
#  9810131: 3,
#  1005: 1,
#  9311183: 52,
#  9506135: 32,
#  9601078: 43,
#  9603097: 121,
#  9611194: 8,
#  9712257: 68,
#  9805026: 5,
#  9811178: 43,
#  9901099: 25,
#  9902132: 50,
#  9904145: 52,
#  9908025: 36,
#  9908036: 94,
#  9908040: 102,
#  9909030: 84,
#  9909114: 26,
#  9909140: 33,
#  9909163: 46,
#  9910148: 10,
#  9912239: 29,
#  208020: 205,
#  9307107: 8,
#  9306145: 28,
#  9309093: 9,
#  9410010: 13,
#  9509105: 30,
#  9409165: 7,
#  9410209: 18,
#  9503207: 89,
#  9506014: 89,
#  9511043: 213,
#  9411134: 9,
#  9506186: 7,
#  9610192: 21,
#  9611124: 9,
#  9309105: 10,
#  9509171: 13,
#  9605042: 33,
#  9611064: 4,
#  9612148: 48,
#  9701190: 50,
#  9702037: 37,
#  9702194: 5,
#  9702195: 2,
#  9706057: 13,
#  9707068: 109,
#  9708040: 82,
#  9708141: 44,
#  9708166: 28,
#  9711029: 8,
#  9711069: 18,
#  9712186: 141,
#  9305010: 33,
#  9712197: 30,
#  9807142: 13,
#  9809097: 41,
#  9604128: 23,
#  9607174: 29,
#  9609128: 26,
#  9612010: 11,
#  9612011: 11,
#  9612012: 11,
#  9709216: 14,
#  9806174: 6,
#  9808042: 42,
#  9810022: 22,
#  9810087: 19,
#  9806121: 10,
#  9811211: 15,
#  9609112: 56,
#  9803101: 4,
#  9812193: 109,
#  9903139: 14,
#  9311168: 3,
#  9412109: 1,
#  9606177: 6,
#  9609124: 2,
#  9612078: 15,
#  9712230: 113,
#  9905038: 44,
#  9905078: 9,
#  9204036: 15,
#  9205040: 10,
#  9211130: 9,
#  9212060: 28,
#  9301026: 9,
#  ...}

# %% [markdown]
# ### We want to count how many nodes have a given degree-in
# The Counter module is a dictionary subclass that allows quick item counting.

# %%
from collections import Counter 
degin_distri=Counter(H.in_degree().values())
degin_distri
# Out:
# Counter({0: 4590,
#          1: 3787,
#          2: 2700,
#          3: 1992,
#          4: 1643,
#          5: 1327,
#          6: 1134,
#          7: 903,
#          8: 823,
#          9: 692,
#          10: 591,
#          11: 527,
#          12: 484,
#          13: 447,
#          14: 409,
#          15: 322,
#          16: 293,
#          17: 274,
#          18: 278,
#          19: 249,
#          20: 223,
#          21: 185,
#          22: 185,
#          23: 161,
#          24: 161,
#          25: 136,
#          26: 128,
#          27: 126,
#          28: 137,
#          29: 120,
#          30: 127,
#          31: 88,
#          32: 100,
#          33: 88,
#          34: 67,
#          35: 87,
#          36: 66,
#          37: 82,
#          38: 74,
#          39: 67,
#          40: 52,
#          41: 72,
#          42: 53,
#          43: 69,
#          44: 50,
#          45: 56,
#          46: 52,
#          47: 44,
#          48: 29,
#          49: 48,
#          50: 34,
#          51: 33,
#          52: 32,
#          53: 31,
#          54: 33,
#          55: 28,
#          56: 36,
#          57: 29,
#          58: 27,
#          59: 29,
#          60: 25,
#          61: 25,
#          62: 28,
#          63: 23,
#          64: 26,
#          65: 23,
#          66: 21,
#          67: 23,
#          68: 24,
#          69: 19,
#          70: 22,
#          71: 21,
#          72: 10,
#          73: 17,
#          74: 13,
#          75: 19,
#          76: 18,
#          77: 15,
#          78: 8,
#          79: 24,
#          80: 9,
#          81: 12,
#          82: 15,
#          83: 8,
#          84: 11,
#          85: 14,
#          86: 7,
#          87: 13,
#          88: 10,
#          89: 14,
#          90: 6,
#          91: 7,
#          92: 9,
#          93: 6,
#          94: 17,
#          95: 10,
#          96: 10,
#          97: 10,
#          98: 4,
#          99: 9,
#          100: 7,
#          101: 9,
#          102: 9,
#          103: 4,
#          104: 6,
#          105: 8,
#          106: 10,
#          107: 8,
#          108: 6,
#          109: 8,
#          110: 5,
#          111: 5,
#          112: 3,
#          113: 9,
#          114: 8,
#          115: 5,
#          116: 6,
#          117: 3,
#          118: 8,
#          119: 5,
#          120: 2,
#          121: 5,
#          122: 3,
#          123: 4,
#          124: 6,
#          125: 5,
#          126: 5,
#          127: 2,
#          129: 5,
#          130: 1,
#          131: 4,
#          132: 1,
#          133: 6,
#          134: 3,
#          135: 1,
#          136: 6,
#          137: 3,
#          138: 3,
#          139: 4,
#          140: 1,
#          141: 4,
#          142: 6,
#          143: 2,
#          144: 6,
#          145: 3,
#          146: 3,
#          147: 1,
#          148: 6,
#          149: 4,
#          150: 4,
#          151: 5,
#          152: 2,
#          153: 3,
#          154: 4,
#          155: 4,
#          156: 2,
#          157: 4,
#          158: 3,
#          159: 5,
#          160: 1,
#          162: 2,
#          164: 3,
#          165: 1,
#          167: 2,
#          168: 1,
#          169: 2,
#          171: 2,
#          172: 6,
#          173: 2,
#          174: 2,
#          175: 1,
#          176: 2,
#          177: 2,
#          178: 2,
#          179: 2,
#          180: 1,
#          181: 1,
#          182: 1,
#          183: 1,
#          184: 1,
#          185: 1,
#          186: 3,
#          187: 1,
#          188: 2,
#          189: 1,
#          190: 3,
#          191: 2,
#          192: 2,
#          193: 2,
#          194: 2,
#          196: 3,
#          197: 2,
#          198: 1,
#          199: 1,
#          201: 3,
#          204: 3,
#          205: 4,
#          208: 2,
#          211: 1,
#          212: 1,
#          213: 1,
#          214: 1,
#          217: 1,
#          219: 1,
#          220: 2,
#          222: 2,
#          223: 4,
#          224: 1,
#          225: 1,
#          228: 2,
#          229: 3,
#          230: 2,
#          232: 3,
#          233: 2,
#          235: 1,
#          240: 1,
#          242: 2,
#          244: 1,
#          247: 1,
#          248: 1,
#          251: 1,
#          252: 1,
#          257: 2,
#          264: 1,
#          265: 1,
#          268: 1,
#          273: 1,
#          274: 1,
#          282: 2,
#          290: 1,
#          295: 1,
#          297: 1,
#          301: 3,
#          304: 1,
#          308: 1,
#          314: 1,
#          315: 1,
#          325: 2,
#          327: 2,
#          328: 2,
#          329: 2,
#          331: 1,
#          333: 1,
#          337: 1,
#          340: 1,
#          341: 1,
#          344: 1,
#          347: 1,
#          373: 1,
#          380: 2,
#          383: 1,
#          385: 1,
#          388: 1,
#          406: 1,
#          411: 1,
#          421: 1,
#          424: 1,
#          426: 1,
#          427: 1,
#          438: 1,
#          456: 1,
#          467: 1,
#          475: 1,
#          494: 1,
#          520: 1,
#          651: 1,
#          701: 1,
#          748: 1,
#          775: 1,
#          788: 2,
#          807: 1,
#          1006: 1,
#          1032: 1,
#          1114: 1,
#          1144: 1,
#          1155: 1,
#          1199: 1,
#          1299: 1,
#          1641: 1,
#          1775: 1,
#          2414: 1})

# %%
x=[]
y=[]
for i in sorted(degin_distri):   
    x.append(i)
    y.append(float(degin_distri[i])/len(H))

plt.figure(figsize=(10,7))    
plt.plot(np.array(x),np.array(y))

plt.xlabel('$k_{in}$', fontsize=18)
plt.ylabel('$P(k_{in})$', fontsize=18)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.yscale('log')
plt.xscale('log')
plt.axis([1,10000,0.00001,1.0])
plt.show()

# %% [markdown]
# Let's plot the degree out distribution

# %%
degout_distri=Counter(H.out_degree().values())
degout_distri
# Out:
# Counter({0: 2711,
#          1: 2449,
#          2: 1951,
#          3: 1657,
#          4: 1405,
#          5: 1272,
#          6: 1172,
#          7: 1087,
#          8: 975,
#          9: 847,
#          10: 790,
#          11: 771,
#          12: 651,
#          13: 640,
#          14: 622,
#          15: 556,
#          16: 519,
#          17: 503,
#          18: 498,
#          19: 429,
#          20: 412,
#          21: 398,
#          22: 384,
#          23: 339,
#          24: 304,
#          25: 333,
#          26: 284,
#          27: 250,
#          28: 244,
#          29: 246,
#          30: 240,
#          31: 184,
#          32: 194,
#          33: 160,
#          34: 166,
#          35: 162,
#          36: 149,
#          37: 135,
#          38: 111,
#          39: 114,
#          40: 104,
#          41: 98,
#          42: 91,
#          43: 81,
#          44: 77,
#          45: 61,
#          46: 55,
#          47: 60,
#          48: 51,
#          49: 48,
#          50: 45,
#          51: 45,
#          52: 39,
#          53: 32,
#          54: 34,
#          55: 37,
#          56: 31,
#          57: 33,
#          58: 35,
#          59: 23,
#          60: 14,
#          61: 10,
#          62: 16,
#          63: 23,
#          64: 17,
#          65: 17,
#          66: 15,
#          67: 14,
#          68: 10,
#          69: 13,
#          70: 14,
#          71: 13,
#          72: 6,
#          73: 11,
#          74: 7,
#          75: 8,
#          76: 4,
#          77: 8,
#          78: 7,
#          79: 6,
#          80: 5,
#          81: 5,
#          82: 5,
#          83: 6,
#          84: 4,
#          85: 3,
#          86: 5,
#          87: 1,
#          88: 3,
#          89: 4,
#          90: 5,
#          91: 2,
#          92: 1,
#          93: 4,
#          94: 1,
#          95: 3,
#          96: 3,
#          97: 2,
#          98: 1,
#          99: 4,
#          100: 1,
#          101: 2,
#          102: 1,
#          103: 1,
#          104: 4,
#          106: 4,
#          107: 1,
#          108: 2,
#          109: 2,
#          112: 1,
#          115: 2,
#          120: 2,
#          121: 4,
#          122: 2,
#          123: 1,
#          124: 1,
#          125: 1,
#          126: 2,
#          134: 3,
#          135: 1,
#          136: 1,
#          139: 1,
#          142: 1,
#          143: 1,
#          146: 1,
#          149: 1,
#          154: 3,
#          156: 1,
#          157: 1,
#          158: 1,
#          159: 1,
#          160: 1,
#          165: 1,
#          167: 1,
#          169: 1,
#          170: 1,
#          175: 1,
#          177: 1,
#          180: 1,
#          181: 1,
#          198: 1,
#          200: 1,
#          201: 1,
#          207: 1,
#          211: 1,
#          212: 1,
#          214: 1,
#          216: 1,
#          226: 1,
#          246: 1,
#          263: 1,
#          274: 1,
#          289: 1,
#          302: 1,
#          359: 1,
#          562: 1})

# %%
x=[]
y=[]
for i in sorted(degout_distri):   
    x.append(i)
    y.append(float(degout_distri[i])/len(H))

plt.figure(figsize=(10,7))    
plt.plot(np.array(x),np.array(y))

plt.xlabel('$k_{out}$', fontsize=18)
plt.ylabel('$P(k_{out})$', fontsize=18)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.yscale('log')
plt.xscale('log')
plt.axis([1,10000,0.00001,1.0])
plt.show()

# %% [markdown]
# ### Export to gml (be careful this is a large network!)

# %% [markdown]
# The file in gml format can be visualized using the software tool Gephi (http://gephi.org).

# %%
nx.write_gml(H,'./citHepTh.gml')

# %% [markdown]
# # Visualizing a network with NetworkX

# %% [markdown]
# NetworkX combined with matplotlib can be used to visualize complex networks.
#
# It provides a good range of functionalities to obtain some basic and more refined visualization. More details are available in the [documentation](https://networkx.github.io/documentation/development/reference/drawing.html).

# %% [markdown]
# Notice, as stated in the documentation
# >NetworkX provides basic functionality for visualizing graphs, but its main goal is to enable graph analysis rather than perform graph visualization.
# >In the future, graph visualization functionality may be removed from NetworkX or only available as an add-on package.

# %% [markdown]
# We generate a random Erdos-Renyi network and visualize it.

# %%
N=100
prob=0.05

# %%
ER=nx.erdos_renyi_graph(N, prob)

# %%
plt.figure(figsize=(8,6))
nx.draw_networkx(ER)

# %%
plt.figure(figsize=(8,6))
nx.draw_circular(ER) #generates a warning because networkX is not fully ported to py3
# Out:
# /usr/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /usr/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /usr/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /usr/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
plt.figure(figsize=(8,6))
nx.draw_random(ER)
# Out:
# /usr/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /usr/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /usr/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /usr/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
plt.figure(figsize=(8,6))
nx.draw_spring(ER)
# Out:
# /usr/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /usr/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /usr/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /usr/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
pos=nx.spring_layout(ER)
pos
# Out:
# {0: array([ 0.52084214,  0.75731972]),
#  1: array([ 0.57294423,  0.66546351]),
#  2: array([ 0.24830876,  0.37728438]),
#  3: array([ 0.30280844,  0.6885027 ]),
#  4: array([ 0.46440353,  0.38297426]),
#  5: array([ 0.51864011,  0.3045049 ]),
#  6: array([ 0.31061011,  0.20432188]),
#  7: array([ 0.57226893,  0.18609145]),
#  8: array([ 0.54897574,  0.35917545]),
#  9: array([ 0.45693153,  0.05899904]),
#  10: array([ 0.        ,  0.47023095]),
#  11: array([ 0.17584222,  0.70563809]),
#  12: array([ 0.7095129 ,  0.63251889]),
#  13: array([ 0.56998542,  0.46328233]),
#  14: array([ 0.59623063,  0.91012815]),
#  15: array([ 0.39175069,  0.55429113]),
#  16: array([ 0.31231096,  0.51752   ]),
#  17: array([ 0.23555453,  0.56018584]),
#  18: array([ 0.61402339,  0.60293862]),
#  19: array([ 0.42428243,  0.61570386]),
#  20: array([ 0.39710661,  0.31631759]),
#  21: array([ 0.5156515 ,  0.56943013]),
#  22: array([ 0.55983182,  0.58857924]),
#  23: array([ 0.07103815,  0.21375881]),
#  24: array([ 0.52946449,  0.08989657]),
#  25: array([ 0.07398172,  0.70884625]),
#  26: array([ 0.49425908,  0.40974046]),
#  27: array([ 0.4176177 ,  0.39980994]),
#  28: array([ 0.28138013,  0.56213127]),
#  29: array([ 0.5219414 ,  0.19478036]),
#  30: array([ 0.11825319,  0.52082526]),
#  31: array([ 0.19096474,  0.50437287]),
#  32: array([ 0.45312098,  0.78266374]),
#  33: array([ 0.29979793,  0.95360608]),
#  34: array([ 0.54048995,  0.9320486 ]),
#  35: array([ 0.03617861,  0.24640093]),
#  36: array([ 0.97284804,  0.36401553]),
#  37: array([ 0.32347774,  0.11305716]),
#  38: array([ 0.00387223,  0.65072425]),
#  39: array([ 0.62167191,  0.32996645]),
#  40: array([ 0.65701125,  0.6507728 ]),
#  41: array([ 0.58235669,  0.72757003]),
#  42: array([ 0.60613321,  0.24526404]),
#  43: array([ 0.84334095,  0.52625549]),
#  44: array([ 0.70632899,  0.75999405]),
#  45: array([ 0.77027459,  0.36057927]),
#  46: array([ 0.4454195 ,  0.69280498]),
#  47: array([ 0.05714711,  0.50292085]),
#  48: array([ 0.30831088,  0.46160148]),
#  49: array([ 0.77354336,  0.66312672]),
#  50: array([ 0.81113276,  0.4797469 ]),
#  51: array([ 0.68349706,  0.3264159 ]),
#  52: array([ 0.37577411,  0.39983414]),
#  53: array([ 0.96590389,  0.33420128]),
#  54: array([ 0.37229257,  0.62554659]),
#  55: array([ 0.67780727,  0.70413862]),
#  56: array([ 0.82457043,  0.41732707]),
#  57: array([ 0.13072357,  0.33712934]),
#  58: array([ 0.43982707,  0.81387407]),
#  59: array([ 0.38297783,  0.        ]),
#  60: array([ 0.46838851,  0.03220846]),
#  61: array([ 0.67795825,  0.96024728]),
#  62: array([ 0.66694274,  0.4052841 ]),
#  63: array([ 0.1755393 ,  0.64527353]),
#  64: array([ 0.46113633,  0.9279634 ]),
#  65: array([ 0.63649854,  0.7911985 ]),
#  66: array([ 0.92552085,  0.72452281]),
#  67: array([ 0.36614693,  0.79896166]),
#  68: array([ 0.20408641,  0.17385941]),
#  69: array([ 1.        ,  0.55229635]),
#  70: array([ 0.63538813,  0.50245722]),
#  71: array([ 0.72903382,  0.94798646]),
#  72: array([ 0.40009937,  0.66587406]),
#  73: array([ 0.19143137,  0.84196343]),
#  74: array([ 0.30720766,  0.36416833]),
#  75: array([ 0.90979099,  0.20770268]),
#  76: array([ 0.49486983,  0.46882933]),
#  77: array([ 0.86004447,  0.60050239]),
#  78: array([ 0.02341204,  0.27386135]),
#  79: array([ 0.40080957,  0.49281865]),
#  80: array([ 0.69373544,  0.84382448]),
#  81: array([ 0.4718893 ,  0.35022724]),
#  82: array([ 0.50425711,  0.87396155]),
#  83: array([ 0.47066086,  0.26011923]),
#  84: array([ 0.69553784,  0.2485442 ]),
#  85: array([ 0.23391627,  0.72214326]),
#  86: array([ 0.58948249,  0.39279829]),
#  87: array([ 0.80459697,  0.28979181]),
#  88: array([ 0.39891915,  0.22518895]),
#  89: array([ 0.42903473,  0.11097569]),
#  90: array([ 0.22618428,  0.6106129 ]),
#  91: array([ 0.41641768,  0.98304746]),
#  92: array([ 0.17975831,  0.3363237 ]),
#  93: array([ 0.20661268,  0.43995578]),
#  94: array([ 0.28009704,  0.30288623]),
#  95: array([ 0.68714355,  0.49804909]),
#  96: array([ 0.60207685,  0.53520362]),
#  97: array([ 0.45945996,  0.58273943]),
#  98: array([ 0.80914417,  0.76101496]),
#  99: array([ 0.76888568,  0.54735002])}

# %% [markdown]
# We can draw the network nodes only, and assign a specific location to each node.

# %%
plt.figure(figsize=(8,6))
nx.draw_networkx_nodes(ER, pos)
#plt.axis('off')

# %%
plt.figure(figsize=(8,6))

s=nx.draw_networkx_nodes(ER,
            pos,
            node_size=100.0,
            node_color=list(nx.degree(ER).values()),
            alpha=1,
            cmap=plt.cm.coolwarm
            )

nx.draw_networkx_edges(ER, pos, alpha=0.5)

#show the colorbar on the right side
cbar=plt.colorbar(s)
cbar.ax.set_ylabel('Degree', size=22)

plt.axis('off')
plt.show()

# %% [markdown]
# # Visualizing a spatial network with NetworkX

# %% [markdown]
# We analyze the US airport network of year 2010.
# The network is available from the [network repository of Tore Opshal](https://toreopsahl.com/datasets/#usairports).
#
# Weights represent the total number of passengers who traveled on that connection in a year.
#
# Airport coordinates have been added by myself.

# %%
G=nx.Graph()
fh=open('./USairport_2010.txt','r')
for line in fh.readlines():
    s=line.strip().split()
    G.add_edge(int(s[0]),int(s[1]))
fh.close()

# %%
len(G)
# Out:
# 405

# %% [markdown]
# Is the network fully connected?

# %%
nx.number_connected_components(G)
# Out:
# 2

# %%
c=list(nx.connected_components(G))
c[-1]
# Out:
# {1182, 1347}

# %% [markdown]
# We define three dictionaries associated to the network to store additional node's features: IATA code, aiport name, geographic coordinates.

# %%
G.code={}
G.name={}
G.pos={}

# %% [markdown]
# We extract nodes features from a file

# %%
finfo=open('./USairport_2010_codes.txt','r')
for line in finfo.readlines():
    s=line.strip().split()
    node=int(s[0])
    G.code[node]=s[1]
    G.name[node]=s[2]
    G.pos[node]=[float(s[4]),float(s[3])]
finfo.close()

# %% [markdown]
# Draw the network

# %%
fig=plt.figure(figsize=(10,7))

nx.draw_networkx_nodes(G,
            pos=G.pos,
            node_size=20
            )

nx.draw_networkx_labels(G,
            pos=G.pos,
            labels=G.code
            )


plt.axis('off')
# Out:
# (-127.05403301931048,
#  -65.233466980689499,
#  23.33714761709437,
#  50.012852382905628)

# %% [markdown]
# We would like to draw the edges but there are too many of them.

# %%
len(G.edges())
# Out:
# 8251

# %% [markdown]
# We select only the strongest connections as a subgraph of G by setting a threshold on the annual passengers volume.

# %%
weight_threshold=700000

# %%
H=nx.Graph()

H.pos={}
H.code={}
H.name={}

fh=open('./USairport_2010.txt','r')
for line in fh.readlines():
    s=line.strip().split()
    node1=int(s[0])
    node2=int(s[1])
    
    weight=int(s[2])
    
    if weight>weight_threshold:
        H.add_edge(node1,node2)
        
        H.pos[node1]=G.pos[node1]
        H.pos[node2]=G.pos[node2]
        
        H.code[node1]=G.code[node1]
        H.code[node2]=G.code[node2]
        
        H.name[node1]=G.name[node1]
        H.name[node2]=G.name[node2]
        
fh.close()

# %% [markdown]
# We draw the network and color code the nodes by their degree.

# %%
import math
fig=plt.figure(figsize=(14,10))

s=nx.draw_networkx_nodes(G,
            pos=G.pos,
            node_color=[math.log(G.degree(v)) for v in G],
            node_size=30,
            cmap=plt.cm.YlOrRd
            )

nx.draw_networkx_edges(H,
            pos=G.pos,
            alpha=0.5
            )

nx.draw_networkx_labels(H,
            pos=H.pos,
            labels=H.name
            )

cbar=plt.colorbar(s)
cbar.ax.set_ylabel('$log(k)$', size=22)

plt.axis('off')
# Out:
# (-127.78749857243648,
#  -65.199065578833967,
#  23.338069889061302,
#  50.0119301109387)

# %% [markdown]
# What is the node with the largest degree?

# %%
max(G.degree().items(), key=itemgetter(1))
# Out:
# (389, 192)

# %%
G.name[389]
# Out:
# 'Denver'

# %% [markdown]
# # Data visualization with NetworkX
#
# The easy interface of NetworkX and matplotlib to draw georeferenced data can be used to visualize all type of data points with geo-coordinates.
#
# A nice example comes from the electoral results of the municipality of Turin available at [the Open Data repository AperTO](http://aperto.comune.torino.it/?q=taxonomy/term/111).

# %% [markdown]
# Electoral data can be geo-referenced through the [dataset containing every street number of the city with its coordinates](http://aperto.comune.torino.it/?q=node/504).

# %% [markdown]
# Based on this idea, we created a Web-interface to explore electoral data of the city of Torino: [Il colore di Torino](http://datainterfaces.org/projects/ilcoloreditorino/)
